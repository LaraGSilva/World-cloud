# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from PIL import Image

# %%
# Importando o relatório de vendas

import pandas as pd

# Caminho para o arquivo
file_path = '/Users/laragoncalves/Downloads/LARA.txt'

# Tentando ler o arquivo com a codificação ISO-8859-1
try:
    entrevista_lara = pd.read_csv(file_path, delimiter='\t', encoding='ISO-8859-1')
    display(entrevista_lara)
except UnicodeDecodeError as e:
    print(f"Erro de codificação: {e}")
except FileNotFoundError as e:
    print(f"Arquivo não encontrado: {e}")

#entrevista_lara.head(5)
#print(type(entrevista_lara))

import re
from collections import Counter


texto_inteiro = ''.join(entrevista_lara["FALAS - LARA"].astype(str))

palavras = re.findall(r'\b\w+\b', texto_inteiro.lower())


frequencia_palavras = Counter(palavras)

palavras_ordenadas = sorted(frequencia_palavras.items(), key=lambda x: x[1], reverse=True)

for palavra, count in frequencia_palavras.items():
    print(f"{palavra}: {count}")
# Out:
#                                          FALAS - LARA
# 0   Tenho 20 anos, eu estudo Sistemas de Informaçã...
# 1   Acho que foi uma das áreas que mais me identif...
# 2   Bom, eu gosto bastante de ir na academia, ver ...
# 3   Ah, eu sou mais caseira, mas eu gosto de sair ...
# 4   Ah, eu prefiro ir para um barzinho, que seja u...
# 5   Ah, esse tipo de pessoa que frequenta? Um pess...
# 6   Ah, eu acho que entra na minha rotina quando é...
# 7   Eu gosto mais de destilados, então acho que en...
# 8   Ah, eu gosto. Eu gosto do sabor, principalment...
# 9   Ah, eu gosto de uma coisa mais doce assim. Alg...
# 10  Marca? Acho que, em específico, acho que a ice...
# 11  Ah, eu acho que quando saio assim com os amigo...
# 12  Eu levo em consideração o preço e a composição...
# 13  É, eu acho que um drink se passa de 30 a 32 BR...
# 14  Eu acho que não, pelo menos eu não fico me ate...
# 15  Ah, se eu vou tomar uma cachaça que tem um teo...
# 16  Eu acho que depende muito da ocasião, mas gera...
# 17  Sim, até porque tem muitos ingredientes que eu...
# 18  Eu acho que não importa muito, pelo menos eu n...
# 19  Acho que eu não me atento a isso, porque geral...
# 20  Eu acho que eu não vou tomar uma bebida alcoól...
# 21  Sim, eu acho que se é uma marca que ninguém co...
# 22  Eu acho que é até um preconceito que as pessoa...
# 23  Eu gosto da embalagem, eu acho que é uma embal...
# 24  Acho que a primeira coisa que vem na minha cab...
# 25  Eu acho que em relação à bebida é diferente po...
# 26  Acho que são bons para quem gosta, é uma boa c...
# 27  Eu acho que ele tem um sabor muito forte de ma...
# 28  Eu vou dizer que não, porque tem um gosto muit...
# 29                                               Sim.
# 30  Acho que uma pessoa tomaria xeque mate em um r...
# 31  Eu imagino mais no verão. Acho que tanto faz s...
# 32  Ah, eu acho que eu acharia justo por volta de ...
# 33  Eu acho que até uns 8 BRL eu pagaria, mais que...
# 34  Eu acho que uma pessoa que poderia gostar dess...
# 35                                            Eu acho
# 36   que uma pessoa que gosta de xeque mate, é uma...
# 37  Eu imagino mais no verão. Acho que tanto faz s...
# publicidade: 1
# falando: 1
# embalagem: 2
# bonita: 1
# fontes: 1
# letras: 1
# muita: 2
# letra: 2
# amarelo: 1
# apagada: 1
# poderia: 3
# viva: 1
# primeira: 1
# cabeça: 1
# desse: 1
# jogo: 1
# à: 1
# associação: 1
# cheque: 1
# mate: 9
# tentaram: 1
# inovar: 1
# certa: 1
# bons: 2
# quem: 1
# gosta: 10
# nem: 1
# rum: 2
# guaraná: 4
# entre: 1
# quatro: 1
# agrada: 2
# 100: 2
# fosse: 1
# toda: 1
# vez: 1
# falar: 1
# dois: 2
# outros: 2
# diria: 1
# tá: 1
# termo: 1
# ele: 1
# ofusca: 1
# dos: 1
# bebia: 1
# senti: 1
# equilibrado: 1
# dizer: 1
# xeque: 3
# rolê: 3
# todo: 2
# mundo: 2
# conversando: 1
# depois: 1
# dar: 1
# relaxada: 1
# tranquilizada: 1
# nessa: 1
# perfil: 2
# festa: 4
# agitada: 1
# alta: 1
# rolês: 1
# ambientes: 3
# tranquilos: 3
# imagino: 4
# verão: 6
# tanto: 2
# tarde: 2
# noite: 2
# tanta: 2
# diferença: 2
# voltado: 5
# acharia: 2
# justo: 2
# volta: 2
# 7: 2
# uns: 2
# 8: 2
# pagaria: 2
# dessa: 2
# mulher: 4
# relacionada: 2
# artes: 4
# estuda: 2
# belas: 2
# curso: 2
# nos: 3
# seus: 4
# tranquilidade: 4
# hobbies: 2
# coisas: 2
# agitadas: 1
# balada: 1
# prefere: 2
# calmos: 1
# relaxar: 2
# voltando: 1
# leitura: 1
# escutar: 1
# programas: 1
# sociável: 2
# extrovertida: 1
# curtição: 1
# preza: 1
# estar: 1
# essas: 1
# características: 1
# moderna: 1
# defeitos: 1
# timidez: 1
# introspecção: 1
# arte: 1
# museus: 1
# parques: 1
# ibirapuera: 1
# museu: 1
# ipiranga: 1
# cafés: 1
# bairro: 1
# contém: 1
# chá: 5
# acalmam: 1
# trazem: 1
# aspecto: 1
# traz: 2
# calma: 1
# chás: 1
# desses: 1
# tipos: 1
# mim: 1
# tinha: 1
# conhecimento: 1
# penso: 1
# pensaria: 1
# logo: 1
# misturar: 1
# preferiria: 1
# colocar: 1
# gelo: 1
# gostam: 1
# presente: 1
# voltada: 1
# numa: 1
# consumido: 1
# realmente: 1
# envolve: 1
# estereótipo: 1
# tomado: 1
# acalmar: 1
# tranquilizar: 1
# tirar: 1
# dor: 1
# obrigada: 1

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

image_mask = ~np.array(Image.open('mapa_br.png'))


file_path = '/Users/laragoncalves/Downloads/LARA.txt'

try:
    with open(file_path, 'r', encoding='ISO-8859-1') as file:
        text = file.read()
except UnicodeDecodeError as e:
    print(f"Erro de codificação: {e}")
except FileNotFoundError as e:
    print(f"Arquivo não encontrado: {e}")


wordcloud = WordCloud(width=image_mask.shape[1], height=image_mask.shape[0],mask= image_mask,colormap = 'nipy_spectral_r' ,background_color='white').generate(text)


plt.figure(figsize=(15, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
